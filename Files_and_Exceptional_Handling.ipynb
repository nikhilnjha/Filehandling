# %% [markdown]
# # Theory

# %% [markdown]
# 1.  What is the difference between interpreted and compiled languages?
#
#     In interpreted languages, the source code is executed line by line by an interpreter. This means each line is translated into machine code and executed on the fly, every time the program runs. Think of it like having a translator read a speech to an audience sentence by sentence. Python is an example of an interpreted language.
#
#     Compiled languages, on the other hand, have their entire source code translated into machine code by a compiler before the program is executed. This creates an executable file that can be run directly by the computer's processor. It's like having the entire speech translated and written down beforehand, ready to be read aloud. Examples include C++ and Java (though Java has a bytecode step).
#
# 2.  What is exception handling in Python?
#
#     Exception handling in Python is a mechanism to gracefully manage errors that occur during the execution of a program. Instead of the program crashing abruptly, you can anticipate potential problems (like trying to open a file that doesn't exist) and write code to handle them. This typically involves using `try`, `except`, and optionally `finally` blocks to catch and respond to these errors.
#
# 3.  What is the purpose of the `finally` block in exception handling?
#
#     The `finally` block in exception handling is used to define a set of statements that will *always* be executed, regardless of whether an exception occurred in the `try` block or not, and whether that exception was handled by an `except` block. It's commonly used for cleanup operations, such as closing files or releasing resources, ensuring these actions happen even if errors arise.
#
# 4.  What is logging in Python?
#
#     Logging in Python is a way to track events that occur when your software runs. Instead of just printing to the console, logging allows you to record detailed information about the program's execution, including errors, warnings, informational messages, and debugging details. This information can be saved to files, sent to other systems, or displayed in various formats, making it invaluable for debugging, monitoring, and understanding the behavior of your applications over time.
#
# 5.  What is the significance of the `__init__` method in Python?
#
#     The `__init__` method is a special method (often called a constructor) in Python classes. It is automatically called when a new object (an instance) of the class is created. Its primary purpose is to initialize the attributes (data) of the newly created object. You define the initial state of the object within the `__init__` method by assigning values to its instance variables using `self`.
#
# 6.  What is the difference between `import` and `from ... import ...` in Python?
#
#     The `import` statement imports an entire module. You then access the items within that module using the module name as a prefix (e.g., `import math; result = math.sqrt(16)`).
#
#     The `from ... import ...` statement allows you to import specific names (functions, classes, variables) directly from a module into the current namespace. Once imported this way, you can use these names directly without the module prefix (e.g., `from math import sqrt; result = sqrt(16)`).
#
# 7.  How can you handle multiple exceptions in Python?
#
#     * Multiple `except` blocks: You can have separate `except` blocks for each specific type of exception you want to handle differently:
#         ```python
#         try:
#             # some code that might raise ValueError or TypeError
#             value = int("abc")
#         except ValueError:
#             print("Could not convert to an integer.")
#         except TypeError:
#             print("Incorrect type for conversion.")
#         ```
#     * Catching multiple exceptions in one `except` block: You can use a tuple of exception types in a single `except` block to handle them with the same code:
#         ```python
#         try:
#             # some code that might raise ValueError or TypeError
#             result = 10 / 0
#         except (ValueError, TypeError, ZeroDivisionError) as e:
#             print(f"An error occurred: {e}")
#         ```
#     * Catching a general exception: You can catch a broader `Exception` class (which is the base class for most built-in exceptions) to handle any unexpected errors. However, it's generally better to be more specific with your exception handling when possible.
#
# 8.  What is the purpose of the `with` statement when handling files in Python?
#
#     The `with` statement in Python is used to manage resources, such as files, in a clean and efficient way. When you use `with open(...) as file:`, it guarantees that the file will be automatically closed after the block of code within the `with` statement is finished, even if errors occur. This eliminates the need to explicitly call `file.close()` and helps prevent resource leaks. It works because the file object (and other resources that support it) implements context management protocols (`__enter__` and `__exit__` methods).
#
# 9.  What is the difference between multithreading and multiprocessing?
#
#     Multithreading involves running multiple threads (lightweight units of execution) within a single process. These threads share the same memory space. While it can improve concurrency for I/O-bound tasks (like network requests), it might not achieve true parallelism for CPU-bound tasks in Python due to the Global Interpreter Lock (GIL), which allows only one thread to hold control of the Python interpreter at any given time.
#
#     Multiprocessing, on the other hand, involves running multiple independent processes. Each process has its own memory space. This allows for true parallelism on multi-core processors, making it suitable for CPU-bound tasks. However, inter-process communication (IPC) is more complex as data needs to be explicitly shared between processes.
#
# 10. What are the advantages of using logging in a program?
#
#     * Detailed Information: Logs can record more comprehensive information than simple print statements, including timestamps, severity levels, module names, and line numbers.
#     * Separation of Concerns: Logging separates the task of recording events from the main program logic, making the code cleaner.
#     * Persistence: Log messages can be easily written to files, allowing you to review the program's history and diagnose issues long after it has run.
#     * Severity Levels: Logging allows you to categorize messages by severity (e.g., DEBUG, INFO, WARNING, ERROR, CRITICAL), enabling you to filter and focus on important events.
#     * Debugging and Monitoring: Logs are invaluable for debugging errors, understanding program behavior, and monitoring the health and performance of applications.
#
# 11. What is memory management in Python?
#
#     Memory management in Python involves the automatic allocation and deallocation of memory for objects. Python uses a private heap to store objects. The management of this heap is handled by the Python memory manager.
#
# 12. What are the basic steps involved in exception handling in Python?
#
#     1. `try` block:*Enclose the code that might raise an exception within a `try` block.
#     2. `except` block(s): Follow the `try` block with one or more `except` blocks to specify how to handle different types of exceptions if they occur in the `try` block. You can catch specific exception types or a more general `Exception`.
#     3. Optional `else` block: An optional `else` block can be included after the `except` blocks. The code in the `else` block is executed only if no exceptions were raised in the `try` block.
#     4. Optional `finally` block: An optional `finally` block can be included after the `except` (and `else` if present) blocks. The code in the `finally` block is always executed, regardless of whether an exception occurred or was handled.
#
# 13. Why is memory management important in Python?
#
#     * Preventing Memory Leaks: Automatic memory management helps prevent memory leaks, where memory is allocated but never freed, leading to increased memory consumption and potentially program crashes.
#     * Simplifying Development: It frees developers from the complex and error-prone task of manually allocating and deallocating memory, allowing them to focus on the application's logic.
#     * Resource Efficiency: Efficient memory management ensures that memory resources are used effectively, preventing the program from consuming excessive amounts of memory.
#
# 14. What is the role of `try` and `except` in exception handling?
#
#     The `try` block defines the section of code where an exception might occur. Python will execute the code within the `try` block.
#
#     The `except` block(s) define how the program should respond if a specific exception (or a group of exceptions) occurs within the `try` block. If an exception of the type specified in an `except` clause is raised in the `try` block, the code within that `except` block will be executed. If no matching `except` block is found, the exception will propagate up the call stack, potentially causing the program to terminate if not handled elsewhere.
#
# 15. How does Python's garbage collection system work?
#
#     Python primarily uses reference counting for garbage collection. Every object in Python has a reference counter that keeps track of how many variables or other objects are referring to it. When an object's reference count drops to zero (meaning no other parts of the program are using it), Python automatically deallocates the memory occupied by that object.
#
# 16. What is the purpose of the `else` block in exception handling?
#
#     The `else` block in exception handling is executed only if no exceptions were raised in the preceding `try` block. It provides a place to put code that depends on the successful completion of the `try` block. This can help to keep the `try` block focused on the code that might raise exceptions and separate the code that should run only when things go smoothly.
#
# 17. What are the common logging levels in Python?
#
#     * DEBUG: Detailed information, typically of interest only when diagnosing problems.
#     * INFO: Confirmation that things are working as expected.
#     * WARNING: An indication that something unexpected happened, or indicative of some problem in the near future (e.g., ‘disk space low’). The software is still working as expected.
#     * ERROR: Due to a more serious problem, the software has not been able to perform some function.
#     * CRITICAL: A serious error, indicating that the program itself may be unable to continue running.
#
#
# 18. What is the difference between `os.fork()` and `multiprocessing` in Python?
#
#     `os.fork()` is a low-level system call (available primarily on Unix-like systems) that creates a new process by duplicating the existing (parent) process. The child process is almost an exact copy of the parent, including its memory space, but they become independent processes after the fork. However, sharing data between forked processes can be complex and often involves mechanisms like pipes or shared memory.
#
#     The `multiprocessing` module in Python provides a higher-level, cross-platform way to create and manage processes. It abstracts away some of the complexities of process creation and offers tools for inter-process communication (like `Queue` and `Pipe`) that are easier to use than the raw mechanisms often required with `os.fork()`. `multiprocessing` is generally the preferred way to work with multiple processes in Python, especially for cross-platform compatibility.
#
# 19. What is the importance of closing a file in Python?
#
#     * Resource Management: Operating systems have a limited number of file handles available. Leaving files open can exhaust these resources, preventing other parts of the program or other programs from opening files.
#     * Data Integrity: When you write to a file, the data might be buffered in memory before being written to disk. Closing the file ensures that all buffered data is flushed to the disk, preventing data loss.
#     * File Locking: Open files might be locked by the operating system, preventing other processes (or even the same program) from accessing or modifying them. Closing the file releases these locks.
#     * Preventing Errors: Failing to close files can sometimes lead to unexpected behavior or errors when you try to reopen or manipulate them later in the program.
#
#
# 20. What is the difference between `file.read()` and `file.readline()` in Python?
#
#     * `file.read()`: This method reads the entire content of the file as a single string. If a size argument is provided (e.g., `file.read(10)`), it reads at most that many bytes.
#
#     * `file.readline()`: This method reads a single line from the file, including the newline character (`\n`) at the end of the line (if present). If the end of the file is reached, it returns an empty string. Repeated calls to `readline()` will read the file line by line.
#
# 21. What is the `logging` module in Python used for?
#
#     As discussed in question 4 and 10, the `logging` module in Python is used for tracking events that occur during the execution of a program. It provides a flexible and powerful way to record detailed information about the program's operation, including errors, warnings, informational messages, and debugging details.
#
# 22. What is the `os` module in Python used for in file handling?
#
#     The `os` module in Python provides a way of using operating system-dependent functionality. In the context of file handling, it offers functions for:
#
#     * Path manipulation: Creating, joining, splitting, and normalizing file paths (`os.path.join()`, `os.path.split()`, `os.path.exists()`, etc.).
#     * File and directory operations: Creating directories (`os.mkdir()`, `os.makedirs()`), removing files and directories (`os.remove()`, `os.rmdir()`, `os.removedirs()`), renaming files and directories (`os.rename()`), changing the current working directory (`os.chdir()`), and listing directory contents (`os.listdir()`).
#     * Getting file information: Accessing file metadata like size, modification time, and permissions (`os.path.getsize()`, `os.path.getmtime()`).
#
#
# 23. What are the challenges associated with memory management in Python?
#
#     * Garbage Collection Overhead: The garbage collection process consumes CPU resources and can sometimes introduce pauses in program execution, especially for long-running or memory-intensive applications.
#     * Memory Fragmentation: Over time, the allocation and deallocation of memory can lead to fragmentation, where available memory is broken into small, non-contiguous blocks, making it difficult to allocate large contiguous blocks even if enough total memory is free.
#     * Circular References: While the cyclic garbage collector handles most cases, complex object structures with circular references can sometimes be tricky for the garbage collector.
#     * Large Objects: Handling very large objects can still lead to memory issues if not managed carefully, as copies might be created implicitly in certain operations.
#
# 24. How do you raise an exception manually in Python?
#
#     You can raise an exception manually in Python using the `raise` statement. You need to specify the exception class you want to raise, and you can optionally provide an argument to the exception constructor (often a descriptive error message):
#
#     ```python
#     def check_value(x):
#         if x < 0:
#             raise ValueError("Input value cannot be negative")
#         print("Value is:", x)
#
#     try:
#         check_value(-5)
#     except ValueError as e:
#         print("Caught an error:", e)
#
#     raise TypeError("Something went wrong with the data type")
#     ```
#
#     In this example, if `x` is negative in the `check_value` function, a `ValueError` is raised with a specific message. The second `raise` statement outside the function unconditionally raises a `TypeError`.
#
# 25. **Why is it important to use multithreading in certain applications?**
#
#     Main Point: Multithreading boosts responsiveness and efficiency, especially for tasks that involve waiting (like reading files or network calls).
#
#     Why it Matters:
#
#     * Keeps UIs smooth: Prevents freezing when doing long tasks.
#     * Handles waiting well: While one thread waits for data, others can work.
#     * Easy data sharing: Threads in the same process can share information easily.
#     * Simpler for some tasks: Can make code cleaner for concurrent I/O.

# %% [markdown]
# # Practical

# %% [markdown]
# 1. How can you open a file for writing in Python and write a string to it?

# %%
try:
    with open("my_file.txt", "w") as file:
        file.write("Hello, world!")
    print("String written to my_file.txt")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# String written to my_file.txt

# %% [markdown]
# 2. Write a Python program to read the contents of a file and print each line.

# %%
try:
    with open("my_file.txt", "r") as file:
        for line in file:
            print(line.strip())  # strip() removes leading/trailing whitespace, including newline
except FileNotFoundError:
    print("Error: The file 'my_file.txt' was not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Hello, world!

# %% [markdown]
# 3. How would you handle a case where the file doesn't exist while trying to open it for reading?

# %%
try:
    with open("Nikhil.txt", "r") as file:
        # Perform read operations here (this block won't be reached if the file doesn't exist)
        pass
except FileNotFoundError:
    print("Error: The file 'Nikhil.txt' was not found.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Error: The file 'Nikhil.txt' was not found.

# %% [markdown]
# 4. Write a Python script that reads from one file and writes its content to another file.

# %%
try:
    with open("src.txt", "r") as source_file, open("dest.txt", "w") as dest_file:
        for line in source_file:
            dest_file.write(line)
    print("Content of 'src.txt' copied to 'dest.txt'")
except FileNotFoundError:
    print("Error: One or both of the files were not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Content of 'src.txt' copied to 'dest.txt'

# %% [markdown]
# 5. How would you catch and handle division by zero error in Python?

# %%
def divide(a, b):
  try:
    result = a / b
    return result
  except ZeroDivisionError:
    print("Error: Cannot divide by zero. Its undefined")
  return None

print(divide(10, 2))
print(divide(5, 0))
# Out:
# 5.0
# Error: Cannot divide by zero. Its undefined
# None

# %% [markdown]
# 6. Write a Python program that logs an error message to a log file when a division by zero exception occurs.

# %%
import logging

# Configure logging to write to a file
logging.basicConfig(filename='error_log.txt', level=logging.ERROR)  # Keep it simple

def divide(x, y):
    """Divides two numbers and logs an error if y is zero."""
    if y == 0:
        logging.error("Division by zero occurred.")
        return None
    else:
        return x / y

# Example usage
divide(10, 0)
# Out:
# ERROR:root:Division by zero occurred.

# %% [markdown]
# 7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?

# %%
import logging

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

logging.info("This is an informational message.")
logging.warning("This is a warning message.")
logging.error("This is an error message.")
# Out:
# WARNING:root:This is a warning message.
# ERROR:root:This is an error message.

# %% [markdown]
# 8. Write a program to handle a file opening error using exception handling.

# %%
try:
    with open("potentially_missing_file.txt", "r") as file:
        # Perform file operations
        print("File opened successfully.")
except FileNotFoundError:
    print("Error: The specified file was not found.")
except IOError as e:
    print(f"An input/output error occurred: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Error: The specified file was not found.

# %% [markdown]
# 9. How can you read a file line by line and store its content in a list in Python?

# %%
try:
    with open("src.txt", "r") as file:
        lines = file.readlines()
        for line in lines:
            print(line.strip())
except FileNotFoundError:
    print("Error: The file 'src.txt' was not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Hello Hello
#
# My Name is Nikhil

# %% [markdown]
# 10. How can you append data to an existing file in Python?

# %%
try:
    with open("src.txt", "a") as file:
        file.write("\nNew Line appended.\n")
    print("Data appended to 'src.txt'")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Data appended to 'src.txt'

# %% [markdown]
# 11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.

# %%
md = {"a": 1, "b": 2}

try:
    value = md["c"]
    print(value)
except KeyError:
    print("Error: The key 'c' does not exist in the dictionary.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Error: The key 'c' does not exist in the dictionary.

# %% [markdown]
# 12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions.

# %%
def process_data(data):
    try:
        index = int(data[0])
        value = 10 / int(data[1])
        print(f"Result: {value}")
    except IndexError:
        print("Error: Not enough elements in the data.")
    except ValueError:
        print("Error: Could not convert to an integer.")
    except ZeroDivisionError:
        print("Error: Division by zero.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

process_data(["0", "2"])
process_data(["1"])
process_data(["a", "2"])
process_data(["0", "0"])
process_data(["x", "y"])
# Out:
# Result: 5.0
# Error: Not enough elements in the data.
# Error: Could not convert to an integer.
# Error: Division by zero.
# Error: Could not convert to an integer.

# %% [markdown]
# 13. How would you check if a file exists before attempting to read it in Python?

# %%
import os

file_path = "src.txt"

if os.path.exists(file_path):
    try:
        with open(file_path, "r") as file:
            content = file.read()
            print("File content:\n", content)
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")
else:
    print(f"Error: The file '{file_path}' does not exist.")
# Out:
# File content:
#  Hello Hello
#
# My Name is NikhilNew Line appended.
#
# New Line appended.

# %% [markdown]
# 14. Write a program that uses the logging module to log both informational and error messages.

# %%
import logging

# Configure logging
logging.basicConfig(level=logging.INFO,  # Set the logging level to INFO
                    format='%(asctime)s - %(levelname)s - %(message)s')

def divide(x, y):
    """Divides two numbers and logs an error if y is zero."""
    logging.info(f"Dividing {x} by {y}")  # Log the operation

    if y == 0:
        logging.error("Division by zero")  # Log an error message
        return None  # Handle the error by returning None
    else:
        return x / y

# Example usage
result1 = divide(10, 2)
result2 = divide(10, 0)

print(f"Result 1: {result1}")
print(f"Result 2: {result2}")

logging.info("Program finished")  # Log an informational message at the end

# process_task(4)
# Out:
# ERROR:root:Division by zero
# Result 1: 5.0
# Result 2: None

# %% [markdown]
# 15. Write a Python program that prints the content of a file and handles the case where the file is empty.

# %%
try:
    with open("src.txt", "r") as file:
        content = file.read()
        if not content:
            print("The file is empty.")
        else:
            print("File content:\n", content)
except FileNotFoundError:
    print("Error: The file was not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# File content:
#  Hello Hello
#
# My Name is NikhilNew Line appended.
#
# New Line appended.

# %% [markdown]
# 16. Demonstrate how to use memory profiling to check the memory usage of a small program.

# %%
# Save this as memory_example.py
from memory_profiler import profile

@profile
def my_function():
    my_list = [i for i in range(100000)]
    squared_list = [x**2 for x in my_list]
    del squared_list
    return my_list[-1]

if __name__ == "__main__":
    result = my_function()
    print(f"Result: {result}")
# Out:
# ERROR: Could not find file <ipython-input-46-22bb5031c529>
# NOTE: %mprun can only be used on functions defined in physical files, and not in the IPython environment.
# Result: 99999

# %% [markdown]
# 17. Write a Python program to create and write a list of numbers to a file, one number per line.

# %%
numbers = [1, 5, 10, 15, 20]

try:
    with open("numbers.txt", "w") as file:
        for number in numbers:
            file.write(str(number) + "\n")
    print("Numbers written to numbers.txt")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Numbers written to numbers.txt

# %% [markdown]
# 18. How would you implement a basic logging setup that logs to a file with rotation after 1MB?

# %%
import logging
from logging.handlers import RotatingFileHandler

log_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

log_handler = RotatingFileHandler('my_app.log', maxBytes=1*1024*1024,  # 1 MB
                                   backupCount=5)  # Keep up to 5 backup files
log_handler.setFormatter(log_formatter)

logger = logging.getLogger(__name__)
logger.addHandler(log_handler)
logger.setLevel(logging.INFO)

# Example usage
logger.info("This is an informational message.")
logger.warning("This is a warning message.")
logger.error("This is an error message.")

# You can generate more log messages to see the rotation in action
for i in range(10000):
    logger.info(f"Logging message number {i}")
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:__main__:Logging message number 5000
# INFO:__main__:Logging message number 5001
# INFO:__main__:Logging message number 5002
# INFO:__main__:Logging message number 5003
# INFO:__main__:Logging message number 5004
# INFO:__main__:Logging message number 5005
# INFO:__main__:Logging message number 5006
# INFO:__main__:Logging message number 5007
# INFO:__main__:Logging message number 5008
# INFO:__main__:Logging message number 5009
# INFO:__main__:Logging message number 5010
# INFO:__main__:Logging message number 5011
# INFO:__main__:Logging message number 5012
# INFO:__main__:Logging message number 5013
# INFO:__main__:Logging message number 5014
# INFO:__main__:Logging message number 5015
# INFO:__main__:Logging message number 5016
# INFO:__main__:Logging message number 5017
# INFO:__main__:Logging message number 5018
# INFO:__main__:Logging message number 5019
# INFO:__main__:Logging message number 5020
# INFO:__main__:Logging message number 5021
# INFO:__main__:Logging message number 5022
# INFO:__main__:Logging message number 5023
# INFO:__main__:Logging message number 5024
# INFO:__main__:Logging message number 5025
# INFO:__main__:Logging message number 5026
# INFO:__main__:Logging message number 5027
# INFO:__main__:Logging message number 5028
# INFO:__main__:Logging message number 5029
# INFO:__main__:Logging message number 5030
# INFO:__main__:Logging message number 5031
# INFO:__main__:Logging message number 5032
# INFO:__main__:Logging message number 5033
# INFO:__main__:Logging message number 5034
# INFO:__main__:Logging message number 5035
# INFO:__main__:Logging message number 5036
# INFO:__main__:Logging message number 5037
# INFO:__main__:Logging message number 5038
# INFO:__main__:Logging message number 5039
# INFO:__main__:Logging message number 5040
# INFO:__main__:Logging message number 5041
# INFO:__main__:Logging message number 5042
# INFO:__main__:Logging message number 5043
# INFO:__main__:Logging message number 5044
# INFO:__main__:Logging message number 5045
# INFO:__main__:Logging message number 5046
# INFO:__main__:Logging message number 5047
# INFO:__main__:Logging message number 5048
# INFO:__main__:Logging message number 5049
# INFO:__main__:Logging message number 5050
# INFO:__main__:Logging message number 5051
# INFO:__main__:Logging message number 5052
# INFO:__main__:Logging message number 5053
# INFO:__main__:Logging message number 5054
# INFO:__main__:Logging message number 5055
# INFO:__main__:Logging message number 5056
# INFO:__main__:Logging message number 5057
# INFO:__main__:Logging message number 5058
# INFO:__main__:Logging message number 5059
# INFO:__main__:Logging message number 5060
# INFO:__main__:Logging message number 5061
# INFO:__main__:Logging message number 5062
# INFO:__main__:Logging message number 5063
# INFO:__main__:Logging message number 5064
# INFO:__main__:Logging message number 5065
# INFO:__main__:Logging message number 5066
# INFO:__main__:Logging message number 5067
# INFO:__main__:Logging message number 5068
# INFO:__main__:Logging message number 5069
# INFO:__main__:Logging message number 5070
# INFO:__main__:Logging message number 5071
# INFO:__main__:Logging message number 5072
# INFO:__main__:Logging message number 5073
# INFO:__main__:Logging message number 5074
# INFO:__main__:Logging message number 5075
# INFO:__main__:Logging message number 5076
# INFO:__main__:Logging message number 5077
# INFO:__main__:Logging message number 5078
# INFO:__main__:Logging message number 5079
# INFO:__main__:Logging message number 5080
# INFO:__main__:Logging message number 5081
# INFO:__main__:Logging message number 5082
# INFO:__main__:Logging message number 5083
# INFO:__main__:Logging message number 5084
# INFO:__main__:Logging message number 5085
# INFO:__main__:Logging message number 5086
# INFO:__main__:Logging message number 5087
# INFO:__main__:Logging message number 5088
# INFO:__main__:Logging message number 5089
# INFO:__main__:Logging message number 5090
# INFO:__main__:Logging message number 5091
# INFO:__main__:Logging message number 5092
# INFO:__main__:Logging message number 5093
# INFO:__main__:Logging message number 5094
# INFO:__main__:Logging message number 5095
# INFO:__main__:Logging message number 5096
# INFO:__main__:Logging message number 5097
# INFO:__main__:Logging message number 5098
# INFO:__main__:Logging message number 5099
# INFO:__main__:Logging message number 5100
# INFO:__main__:Logging message number 5101
# INFO:__main__:Logging message number 5102
# INFO:__main__:Logging message number 5103
# INFO:__main__:Logging message number 5104
# INFO:__main__:Logging message number 5105
# INFO:__main__:Logging message number 5106
# INFO:__main__:Logging message number 5107
# INFO:__main__:Logging message number 5108
# INFO:__main__:Logging message number 5109
# INFO:__main__:Logging message number 5110
# INFO:__main__:Logging message number 5111
# INFO:__main__:Logging message number 5112
# INFO:__main__:Logging message number 5113
# INFO:__main__:Logging message number 5114
# INFO:__main__:Logging message number 5115
# INFO:__main__:Logging message number 5116
# INFO:__main__:Logging message number 5117
# INFO:__main__:Logging message number 5118
# INFO:__main__:Logging message number 5119
# INFO:__main__:Logging message number 5120
# INFO:__main__:Logging message number 5121
# INFO:__main__:Logging message number 5122
# INFO:__main__:Logging message number 5123
# INFO:__main__:Logging message number 5124
# INFO:__main__:Logging message number 5125
# INFO:__main__:Logging message number 5126
# INFO:__main__:Logging message number 5127
# INFO:__main__:Logging message number 5128
# INFO:__main__:Logging message number 5129
# INFO:__main__:Logging message number 5130
# INFO:__main__:Logging message number 5131
# INFO:__main__:Logging message number 5132
# INFO:__main__:Logging message number 5133
# INFO:__main__:Logging message number 5134
# INFO:__main__:Logging message number 5135
# INFO:__main__:Logging message number 5136
# INFO:__main__:Logging message number 5137
# INFO:__main__:Logging message number 5138
# INFO:__main__:Logging message number 5139
# INFO:__main__:Logging message number 5140
# INFO:__main__:Logging message number 5141
# INFO:__main__:Logging message number 5142
# INFO:__main__:Logging message number 5143
# INFO:__main__:Logging message number 5144
# INFO:__main__:Logging message number 5145
# INFO:__main__:Logging message number 5146
# INFO:__main__:Logging message number 5147
# INFO:__main__:Logging message number 5148
# INFO:__main__:Logging message number 5149
# INFO:__main__:Logging message number 5150
# INFO:__main__:Logging message number 5151
# INFO:__main__:Logging message number 5152
# INFO:__main__:Logging message number 5153
# INFO:__main__:Logging message number 5154
# INFO:__main__:Logging message number 5155
# INFO:__main__:Logging message number 5156
# INFO:__main__:Logging message number 5157
# INFO:__main__:Logging message number 5158
# INFO:__main__:Logging message number 5159
# INFO:__main__:Logging message number 5160
# INFO:__main__:Logging message number 5161
# INFO:__main__:Logging message number 5162
# INFO:__main__:Logging message number 5163
# INFO:__main__:Logging message number 5164
# INFO:__main__:Logging message number 5165
# INFO:__main__:Logging message number 5166
# INFO:__main__:Logging message number 5167
# INFO:__main__:Logging message number 5168
# INFO:__main__:Logging message number 5169
# INFO:__main__:Logging message number 5170
# INFO:__main__:Logging message number 5171
# INFO:__main__:Logging message number 5172
# INFO:__main__:Logging message number 5173
# INFO:__main__:Logging message number 5174
# INFO:__main__:Logging message number 5175
# INFO:__main__:Logging message number 5176
# INFO:__main__:Logging message number 5177
# INFO:__main__:Logging message number 5178
# INFO:__main__:Logging message number 5179
# INFO:__main__:Logging message number 5180
# INFO:__main__:Logging message number 5181
# INFO:__main__:Logging message number 5182
# INFO:__main__:Logging message number 5183
# INFO:__main__:Logging message number 5184
# INFO:__main__:Logging message number 5185
# INFO:__main__:Logging message number 5186
# INFO:__main__:Logging message number 5187
# INFO:__main__:Logging message number 5188
# INFO:__main__:Logging message number 5189
# INFO:__main__:Logging message number 5190
# INFO:__main__:Logging message number 5191
# INFO:__main__:Logging message number 5192
# INFO:__main__:Logging message number 5193
# INFO:__main__:Logging message number 5194
# INFO:__main__:Logging message number 5195
# INFO:__main__:Logging message number 5196
# INFO:__main__:Logging message number 5197
# INFO:__main__:Logging message number 5198
# INFO:__main__:Logging message number 5199
# INFO:__main__:Logging message number 5200
# INFO:__main__:Logging message number 5201
# INFO:__main__:Logging message number 5202
# INFO:__main__:Logging message number 5203
# INFO:__main__:Logging message number 5204
# INFO:__main__:Logging message number 5205
# INFO:__main__:Logging message number 5206
# INFO:__main__:Logging message number 5207
# INFO:__main__:Logging message number 5208
# INFO:__main__:Logging message number 5209
# INFO:__main__:Logging message number 5210
# INFO:__main__:Logging message number 5211
# INFO:__main__:Logging message number 5212
# INFO:__main__:Logging message number 5213
# INFO:__main__:Logging message number 5214
# INFO:__main__:Logging message number 5215
# INFO:__main__:Logging message number 5216
# INFO:__main__:Logging message number 5217
# INFO:__main__:Logging message number 5218
# INFO:__main__:Logging message number 5219
# INFO:__main__:Logging message number 5220
# INFO:__main__:Logging message number 5221
# INFO:__main__:Logging message number 5222
# INFO:__main__:Logging message number 5223
# INFO:__main__:Logging message number 5224
# INFO:__main__:Logging message number 5225
# INFO:__main__:Logging message number 5226
# INFO:__main__:Logging message number 5227
# INFO:__main__:Logging message number 5228
# INFO:__main__:Logging message number 5229
# INFO:__main__:Logging message number 5230
# INFO:__main__:Logging message number 5231
# INFO:__main__:Logging message number 5232
# INFO:__main__:Logging message number 5233
# INFO:__main__:Logging message number 5234
# INFO:__main__:Logging message number 5235
# INFO:__main__:Logging message number 5236
# INFO:__main__:Logging message number 5237
# INFO:__main__:Logging message number 5238
# INFO:__main__:Logging message number 5239
# INFO:__main__:Logging message number 5240
# INFO:__main__:Logging message number 5241
# INFO:__main__:Logging message number 5242
# INFO:__main__:Logging message number 5243
# INFO:__main__:Logging message number 5244
# INFO:__main__:Logging message number 5245
# INFO:__main__:Logging message number 5246
# INFO:__main__:Logging message number 5247
# INFO:__main__:Logging message number 5248
# INFO:__main__:Logging message number 5249
# INFO:__main__:Logging message number 5250
# INFO:__main__:Logging message number 5251
# INFO:__main__:Logging message number 5252
# INFO:__main__:Logging message number 5253
# INFO:__main__:Logging message number 5254
# INFO:__main__:Logging message number 5255
# INFO:__main__:Logging message number 5256
# INFO:__main__:Logging message number 5257
# INFO:__main__:Logging message number 5258
# INFO:__main__:Logging message number 5259
# INFO:__main__:Logging message number 5260
# INFO:__main__:Logging message number 5261
# INFO:__main__:Logging message number 5262
# INFO:__main__:Logging message number 5263
# INFO:__main__:Logging message number 5264
# INFO:__main__:Logging message number 5265
# INFO:__main__:Logging message number 5266
# INFO:__main__:Logging message number 5267
# INFO:__main__:Logging message number 5268
# INFO:__main__:Logging message number 5269
# INFO:__main__:Logging message number 5270
# INFO:__main__:Logging message number 5271
# INFO:__main__:Logging message number 5272
# INFO:__main__:Logging message number 5273
# INFO:__main__:Logging message number 5274
# INFO:__main__:Logging message number 5275
# INFO:__main__:Logging message number 5276
# INFO:__main__:Logging message number 5277
# INFO:__main__:Logging message number 5278
# INFO:__main__:Logging message number 5279
# INFO:__main__:Logging message number 5280
# INFO:__main__:Logging message number 5281
# INFO:__main__:Logging message number 5282
# INFO:__main__:Logging message number 5283
# INFO:__main__:Logging message number 5284
# INFO:__main__:Logging message number 5285
# INFO:__main__:Logging message number 5286
# INFO:__main__:Logging message number 5287
# INFO:__main__:Logging message number 5288
# INFO:__main__:Logging message number 5289
# INFO:__main__:Logging message number 5290
# INFO:__main__:Logging message number 5291
# INFO:__main__:Logging message number 5292
# INFO:__main__:Logging message number 5293
# INFO:__main__:Logging message number 5294
# INFO:__main__:Logging message number 5295
# INFO:__main__:Logging message number 5296
# INFO:__main__:Logging message number 5297
# INFO:__main__:Logging message number 5298
# INFO:__main__:Logging message number 5299
# INFO:__main__:Logging message number 5300
# INFO:__main__:Logging message number 5301
# INFO:__main__:Logging message number 5302
# INFO:__main__:Logging message number 5303
# INFO:__main__:Logging message number 5304
# INFO:__main__:Logging message number 5305
# INFO:__main__:Logging message number 5306
# INFO:__main__:Logging message number 5307
# INFO:__main__:Logging message number 5308
# INFO:__main__:Logging message number 5309
# INFO:__main__:Logging message number 5310
# INFO:__main__:Logging message number 5311
# INFO:__main__:Logging message number 5312
# INFO:__main__:Logging message number 5313
# INFO:__main__:Logging message number 5314
# INFO:__main__:Logging message number 5315
# INFO:__main__:Logging message number 5316
# INFO:__main__:Logging message number 5317
# INFO:__main__:Logging message number 5318
# INFO:__main__:Logging message number 5319
# INFO:__main__:Logging message number 5320
# INFO:__main__:Logging message number 5321
# INFO:__main__:Logging message number 5322
# INFO:__main__:Logging message number 5323
# INFO:__main__:Logging message number 5324
# INFO:__main__:Logging message number 5325
# INFO:__main__:Logging message number 5326
# INFO:__main__:Logging message number 5327
# INFO:__main__:Logging message number 5328
# INFO:__main__:Logging message number 5329
# INFO:__main__:Logging message number 5330
# INFO:__main__:Logging message number 5331
# INFO:__main__:Logging message number 5332
# INFO:__main__:Logging message number 5333
# INFO:__main__:Logging message number 5334
# INFO:__main__:Logging message number 5335
# INFO:__main__:Logging message number 5336
# INFO:__main__:Logging message number 5337
# INFO:__main__:Logging message number 5338
# INFO:__main__:Logging message number 5339
# INFO:__main__:Logging message number 5340
# INFO:__main__:Logging message number 5341
# INFO:__main__:Logging message number 5342
# INFO:__main__:Logging message number 5343
# INFO:__main__:Logging message number 5344
# INFO:__main__:Logging message number 5345
# INFO:__main__:Logging message number 5346
# INFO:__main__:Logging message number 5347
# INFO:__main__:Logging message number 5348
# INFO:__main__:Logging message number 5349
# INFO:__main__:Logging message number 5350
# INFO:__main__:Logging message number 5351
# INFO:__main__:Logging message number 5352
# INFO:__main__:Logging message number 5353
# INFO:__main__:Logging message number 5354
# INFO:__main__:Logging message number 5355
# INFO:__main__:Logging message number 5356
# INFO:__main__:Logging message number 5357
# INFO:__main__:Logging message number 5358
# INFO:__main__:Logging message number 5359
# INFO:__main__:Logging message number 5360
# INFO:__main__:Logging message number 5361
# INFO:__main__:Logging message number 5362
# INFO:__main__:Logging message number 5363
# INFO:__main__:Logging message number 5364
# INFO:__main__:Logging message number 5365
# INFO:__main__:Logging message number 5366
# INFO:__main__:Logging message number 5367
# INFO:__main__:Logging message number 5368
# INFO:__main__:Logging message number 5369
# INFO:__main__:Logging message number 5370
# INFO:__main__:Logging message number 5371
# INFO:__main__:Logging message number 5372
# INFO:__main__:Logging message number 5373
# INFO:__main__:Logging message number 5374
# INFO:__main__:Logging message number 5375
# INFO:__main__:Logging message number 5376
# INFO:__main__:Logging message number 5377
# INFO:__main__:Logging message number 5378
# INFO:__main__:Logging message number 5379
# INFO:__main__:Logging message number 5380
# INFO:__main__:Logging message number 5381
# INFO:__main__:Logging message number 5382
# INFO:__main__:Logging message number 5383
# INFO:__main__:Logging message number 5384
# INFO:__main__:Logging message number 5385
# INFO:__main__:Logging message number 5386
# INFO:__main__:Logging message number 5387
# INFO:__main__:Logging message number 5388
# INFO:__main__:Logging message number 5389
# INFO:__main__:Logging message number 5390
# INFO:__main__:Logging message number 5391
# INFO:__main__:Logging message number 5392
# INFO:__main__:Logging message number 5393
# INFO:__main__:Logging message number 5394
# INFO:__main__:Logging message number 5395
# INFO:__main__:Logging message number 5396
# INFO:__main__:Logging message number 5397
# INFO:__main__:Logging message number 5398
# INFO:__main__:Logging message number 5399
# INFO:__main__:Logging message number 5400
# INFO:__main__:Logging message number 5401
# INFO:__main__:Logging message number 5402
# INFO:__main__:Logging message number 5403
# INFO:__main__:Logging message number 5404
# INFO:__main__:Logging message number 5405
# INFO:__main__:Logging message number 5406
# INFO:__main__:Logging message number 5407
# INFO:__main__:Logging message number 5408
# INFO:__main__:Logging message number 5409
# INFO:__main__:Logging message number 5410
# INFO:__main__:Logging message number 5411
# INFO:__main__:Logging message number 5412
# INFO:__main__:Logging message number 5413
# INFO:__main__:Logging message number 5414
# INFO:__main__:Logging message number 5415
# INFO:__main__:Logging message number 5416
# INFO:__main__:Logging message number 5417
# INFO:__main__:Logging message number 5418
# INFO:__main__:Logging message number 5419
# INFO:__main__:Logging message number 5420
# INFO:__main__:Logging message number 5421
# INFO:__main__:Logging message number 5422
# INFO:__main__:Logging message number 5423
# INFO:__main__:Logging message number 5424
# INFO:__main__:Logging message number 5425
# INFO:__main__:Logging message number 5426
# INFO:__main__:Logging message number 5427
# INFO:__main__:Logging message number 5428
# INFO:__main__:Logging message number 5429
# INFO:__main__:Logging message number 5430
# INFO:__main__:Logging message number 5431
# INFO:__main__:Logging message number 5432
# INFO:__main__:Logging message number 5433
# INFO:__main__:Logging message number 5434
# INFO:__main__:Logging message number 5435
# INFO:__main__:Logging message number 5436
# INFO:__main__:Logging message number 5437
# INFO:__main__:Logging message number 5438
# INFO:__main__:Logging message number 5439
# INFO:__main__:Logging message number 5440
# INFO:__main__:Logging message number 5441
# INFO:__main__:Logging message number 5442
# INFO:__main__:Logging message number 5443
# INFO:__main__:Logging message number 5444
# INFO:__main__:Logging message number 5445
# INFO:__main__:Logging message number 5446
# INFO:__main__:Logging message number 5447
# INFO:__main__:Logging message number 5448
# INFO:__main__:Logging message number 5449
# INFO:__main__:Logging message number 5450
# INFO:__main__:Logging message number 5451
# INFO:__main__:Logging message number 5452
# INFO:__main__:Logging message number 5453
# INFO:__main__:Logging message number 5454
# INFO:__main__:Logging message number 5455
# INFO:__main__:Logging message number 5456
# INFO:__main__:Logging message number 5457
# INFO:__main__:Logging message number 5458
# INFO:__main__:Logging message number 5459
# INFO:__main__:Logging message number 5460
# INFO:__main__:Logging message number 5461
# INFO:__main__:Logging message number 5462
# INFO:__main__:Logging message number 5463
# INFO:__main__:Logging message number 5464
# INFO:__main__:Logging message number 5465
# INFO:__main__:Logging message number 5466
# INFO:__main__:Logging message number 5467
# INFO:__main__:Logging message number 5468
# INFO:__main__:Logging message number 5469
# INFO:__main__:Logging message number 5470
# INFO:__main__:Logging message number 5471
# INFO:__main__:Logging message number 5472
# INFO:__main__:Logging message number 5473
# INFO:__main__:Logging message number 5474
# INFO:__main__:Logging message number 5475
# INFO:__main__:Logging message number 5476
# INFO:__main__:Logging message number 5477
# INFO:__main__:Logging message number 5478
# INFO:__main__:Logging message number 5479
# INFO:__main__:Logging message number 5480
# INFO:__main__:Logging message number 5481
# INFO:__main__:Logging message number 5482
# INFO:__main__:Logging message number 5483
# INFO:__main__:Logging message number 5484
# INFO:__main__:Logging message number 5485
# INFO:__main__:Logging message number 5486
# INFO:__main__:Logging message number 5487
# INFO:__main__:Logging message number 5488
# INFO:__main__:Logging message number 5489
# INFO:__main__:Logging message number 5490
# INFO:__main__:Logging message number 5491
# INFO:__main__:Logging message number 5492
# INFO:__main__:Logging message number 5493
# INFO:__main__:Logging message number 5494
# INFO:__main__:Logging message number 5495
# INFO:__main__:Logging message number 5496
# INFO:__main__:Logging message number 5497
# INFO:__main__:Logging message number 5498
# INFO:__main__:Logging message number 5499
# INFO:__main__:Logging message number 5500
# INFO:__main__:Logging message number 5501
# INFO:__main__:Logging message number 5502
# INFO:__main__:Logging message number 5503
# INFO:__main__:Logging message number 5504
# INFO:__main__:Logging message number 5505
# INFO:__main__:Logging message number 5506
# INFO:__main__:Logging message number 5507
# INFO:__main__:Logging message number 5508
# INFO:__main__:Logging message number 5509
# INFO:__main__:Logging message number 5510
# INFO:__main__:Logging message number 5511
# INFO:__main__:Logging message number 5512
# INFO:__main__:Logging message number 5513
# INFO:__main__:Logging message number 5514
# INFO:__main__:Logging message number 5515
# INFO:__main__:Logging message number 5516
# INFO:__main__:Logging message number 5517
# INFO:__main__:Logging message number 5518
# INFO:__main__:Logging message number 5519
# INFO:__main__:Logging message number 5520
# INFO:__main__:Logging message number 5521
# INFO:__main__:Logging message number 5522
# INFO:__main__:Logging message number 5523
# INFO:__main__:Logging message number 5524
# INFO:__main__:Logging message number 5525
# INFO:__main__:Logging message number 5526
# INFO:__main__:Logging message number 5527
# INFO:__main__:Logging message number 5528
# INFO:__main__:Logging message number 5529
# INFO:__main__:Logging message number 5530
# INFO:__main__:Logging message number 5531
# INFO:__main__:Logging message number 5532
# INFO:__main__:Logging message number 5533
# INFO:__main__:Logging message number 5534
# INFO:__main__:Logging message number 5535
# INFO:__main__:Logging message number 5536
# INFO:__main__:Logging message number 5537
# INFO:__main__:Logging message number 5538
# INFO:__main__:Logging message number 5539
# INFO:__main__:Logging message number 5540
# INFO:__main__:Logging message number 5541
# INFO:__main__:Logging message number 5542
# INFO:__main__:Logging message number 5543
# INFO:__main__:Logging message number 5544
# INFO:__main__:Logging message number 5545
# INFO:__main__:Logging message number 5546
# INFO:__main__:Logging message number 5547
# INFO:__main__:Logging message number 5548
# INFO:__main__:Logging message number 5549
# INFO:__main__:Logging message number 5550
# INFO:__main__:Logging message number 5551
# INFO:__main__:Logging message number 5552
# INFO:__main__:Logging message number 5553
# INFO:__main__:Logging message number 5554
# INFO:__main__:Logging message number 5555
# INFO:__main__:Logging message number 5556
# INFO:__main__:Logging message number 5557
# INFO:__main__:Logging message number 5558
# INFO:__main__:Logging message number 5559
# INFO:__main__:Logging message number 5560
# INFO:__main__:Logging message number 5561
# INFO:__main__:Logging message number 5562
# INFO:__main__:Logging message number 5563
# INFO:__main__:Logging message number 5564
# INFO:__main__:Logging message number 5565
# INFO:__main__:Logging message number 5566
# INFO:__main__:Logging message number 5567
# INFO:__main__:Logging message number 5568
# INFO:__main__:Logging message number 5569
# INFO:__main__:Logging message number 5570
# INFO:__main__:Logging message number 5571
# INFO:__main__:Logging message number 5572
# INFO:__main__:Logging message number 5573
# INFO:__main__:Logging message number 5574
# INFO:__main__:Logging message number 5575
# INFO:__main__:Logging message number 5576
# INFO:__main__:Logging message number 5577
# INFO:__main__:Logging message number 5578
# INFO:__main__:Logging message number 5579
# INFO:__main__:Logging message number 5580
# INFO:__main__:Logging message number 5581
# INFO:__main__:Logging message number 5582
# INFO:__main__:Logging message number 5583
# INFO:__main__:Logging message number 5584
# INFO:__main__:Logging message number 5585
# INFO:__main__:Logging message number 5586
# INFO:__main__:Logging message number 5587
# INFO:__main__:Logging message number 5588
# INFO:__main__:Logging message number 5589
# INFO:__main__:Logging message number 5590
# INFO:__main__:Logging message number 5591
# INFO:__main__:Logging message number 5592
# INFO:__main__:Logging message number 5593
# INFO:__main__:Logging message number 5594
# INFO:__main__:Logging message number 5595
# INFO:__main__:Logging message number 5596
# INFO:__main__:Logging message number 5597
# INFO:__main__:Logging message number 5598
# INFO:__main__:Logging message number 5599
# INFO:__main__:Logging message number 5600
# INFO:__main__:Logging message number 5601
# INFO:__main__:Logging message number 5602
# INFO:__main__:Logging message number 5603
# INFO:__main__:Logging message number 5604
# INFO:__main__:Logging message number 5605
# INFO:__main__:Logging message number 5606
# INFO:__main__:Logging message number 5607
# INFO:__main__:Logging message number 5608
# INFO:__main__:Logging message number 5609
# INFO:__main__:Logging message number 5610
# INFO:__main__:Logging message number 5611
# INFO:__main__:Logging message number 5612
# INFO:__main__:Logging message number 5613
# INFO:__main__:Logging message number 5614
# INFO:__main__:Logging message number 5615
# INFO:__main__:Logging message number 5616
# INFO:__main__:Logging message number 5617
# INFO:__main__:Logging message number 5618
# INFO:__main__:Logging message number 5619
# INFO:__main__:Logging message number 5620
# INFO:__main__:Logging message number 5621
# INFO:__main__:Logging message number 5622
# INFO:__main__:Logging message number 5623
# INFO:__main__:Logging message number 5624
# INFO:__main__:Logging message number 5625
# INFO:__main__:Logging message number 5626
# INFO:__main__:Logging message number 5627
# INFO:__main__:Logging message number 5628
# INFO:__main__:Logging message number 5629
# INFO:__main__:Logging message number 5630
# INFO:__main__:Logging message number 5631
# INFO:__main__:Logging message number 5632
# INFO:__main__:Logging message number 5633
# INFO:__main__:Logging message number 5634
# INFO:__main__:Logging message number 5635
# INFO:__main__:Logging message number 5636
# INFO:__main__:Logging message number 5637
# INFO:__main__:Logging message number 5638
# INFO:__main__:Logging message number 5639
# INFO:__main__:Logging message number 5640
# INFO:__main__:Logging message number 5641
# INFO:__main__:Logging message number 5642
# INFO:__main__:Logging message number 5643
# INFO:__main__:Logging message number 5644
# INFO:__main__:Logging message number 5645
# INFO:__main__:Logging message number 5646
# INFO:__main__:Logging message number 5647
# INFO:__main__:Logging message number 5648
# INFO:__main__:Logging message number 5649
# INFO:__main__:Logging message number 5650
# INFO:__main__:Logging message number 5651
# INFO:__main__:Logging message number 5652
# INFO:__main__:Logging message number 5653
# INFO:__main__:Logging message number 5654
# INFO:__main__:Logging message number 5655
# INFO:__main__:Logging message number 5656
# INFO:__main__:Logging message number 5657
# INFO:__main__:Logging message number 5658
# INFO:__main__:Logging message number 5659
# INFO:__main__:Logging message number 5660
# INFO:__main__:Logging message number 5661
# INFO:__main__:Logging message number 5662
# INFO:__main__:Logging message number 5663
# INFO:__main__:Logging message number 5664
# INFO:__main__:Logging message number 5665
# INFO:__main__:Logging message number 5666
# INFO:__main__:Logging message number 5667
# INFO:__main__:Logging message number 5668
# INFO:__main__:Logging message number 5669
# INFO:__main__:Logging message number 5670
# INFO:__main__:Logging message number 5671
# INFO:__main__:Logging message number 5672
# INFO:__main__:Logging message number 5673
# INFO:__main__:Logging message number 5674
# INFO:__main__:Logging message number 5675
# INFO:__main__:Logging message number 5676
# INFO:__main__:Logging message number 5677
# INFO:__main__:Logging message number 5678
# INFO:__main__:Logging message number 5679
# INFO:__main__:Logging message number 5680
# INFO:__main__:Logging message number 5681
# INFO:__main__:Logging message number 5682
# INFO:__main__:Logging message number 5683
# INFO:__main__:Logging message number 5684
# INFO:__main__:Logging message number 5685
# INFO:__main__:Logging message number 5686
# INFO:__main__:Logging message number 5687
# INFO:__main__:Logging message number 5688
# INFO:__main__:Logging message number 5689
# INFO:__main__:Logging message number 5690
# INFO:__main__:Logging message number 5691
# INFO:__main__:Logging message number 5692
# INFO:__main__:Logging message number 5693
# INFO:__main__:Logging message number 5694
# INFO:__main__:Logging message number 5695
# INFO:__main__:Logging message number 5696
# INFO:__main__:Logging message number 5697
# INFO:__main__:Logging message number 5698
# INFO:__main__:Logging message number 5699
# INFO:__main__:Logging message number 5700
# INFO:__main__:Logging message number 5701
# INFO:__main__:Logging message number 5702
# INFO:__main__:Logging message number 5703
# INFO:__main__:Logging message number 5704
# INFO:__main__:Logging message number 5705
# INFO:__main__:Logging message number 5706
# INFO:__main__:Logging message number 5707
# INFO:__main__:Logging message number 5708
# INFO:__main__:Logging message number 5709
# INFO:__main__:Logging message number 5710
# INFO:__main__:Logging message number 5711
# INFO:__main__:Logging message number 5712
# INFO:__main__:Logging message number 5713
# INFO:__main__:Logging message number 5714
# INFO:__main__:Logging message number 5715
# INFO:__main__:Logging message number 5716
# INFO:__main__:Logging message number 5717
# INFO:__main__:Logging message number 5718
# INFO:__main__:Logging message number 5719
# INFO:__main__:Logging message number 5720
# INFO:__main__:Logging message number 5721
# INFO:__main__:Logging message number 5722
# INFO:__main__:Logging message number 5723
# INFO:__main__:Logging message number 5724
# INFO:__main__:Logging message number 5725
# INFO:__main__:Logging message number 5726
# INFO:__main__:Logging message number 5727
# INFO:__main__:Logging message number 5728
# INFO:__main__:Logging message number 5729
# INFO:__main__:Logging message number 5730
# INFO:__main__:Logging message number 5731
# INFO:__main__:Logging message number 5732
# INFO:__main__:Logging message number 5733
# INFO:__main__:Logging message number 5734
# INFO:__main__:Logging message number 5735
# INFO:__main__:Logging message number 5736
# INFO:__main__:Logging message number 5737
# INFO:__main__:Logging message number 5738
# INFO:__main__:Logging message number 5739
# INFO:__main__:Logging message number 5740
# INFO:__main__:Logging message number 5741
# INFO:__main__:Logging message number 5742
# INFO:__main__:Logging message number 5743
# INFO:__main__:Logging message number 5744
# INFO:__main__:Logging message number 5745
# INFO:__main__:Logging message number 5746
# INFO:__main__:Logging message number 5747
# INFO:__main__:Logging message number 5748
# INFO:__main__:Logging message number 5749
# INFO:__main__:Logging message number 5750
# INFO:__main__:Logging message number 5751
# INFO:__main__:Logging message number 5752
# INFO:__main__:Logging message number 5753
# INFO:__main__:Logging message number 5754
# INFO:__main__:Logging message number 5755
# INFO:__main__:Logging message number 5756
# INFO:__main__:Logging message number 5757
# INFO:__main__:Logging message number 5758
# INFO:__main__:Logging message number 5759
# INFO:__main__:Logging message number 5760
# INFO:__main__:Logging message number 5761
# INFO:__main__:Logging message number 5762
# INFO:__main__:Logging message number 5763
# INFO:__main__:Logging message number 5764
# INFO:__main__:Logging message number 5765
# INFO:__main__:Logging message number 5766
# INFO:__main__:Logging message number 5767
# INFO:__main__:Logging message number 5768
# INFO:__main__:Logging message number 5769
# INFO:__main__:Logging message number 5770
# INFO:__main__:Logging message number 5771
# INFO:__main__:Logging message number 5772
# INFO:__main__:Logging message number 5773
# INFO:__main__:Logging message number 5774
# INFO:__main__:Logging message number 5775
# INFO:__main__:Logging message number 5776
# INFO:__main__:Logging message number 5777
# INFO:__main__:Logging message number 5778
# INFO:__main__:Logging message number 5779
# INFO:__main__:Logging message number 5780
# INFO:__main__:Logging message number 5781
# INFO:__main__:Logging message number 5782
# INFO:__main__:Logging message number 5783
# INFO:__main__:Logging message number 5784
# INFO:__main__:Logging message number 5785
# INFO:__main__:Logging message number 5786
# INFO:__main__:Logging message number 5787
# INFO:__main__:Logging message number 5788
# INFO:__main__:Logging message number 5789
# INFO:__main__:Logging message number 5790
# INFO:__main__:Logging message number 5791
# INFO:__main__:Logging message number 5792
# INFO:__main__:Logging message number 5793
# INFO:__main__:Logging message number 5794
# INFO:__main__:Logging message number 5795
# INFO:__main__:Logging message number 5796
# INFO:__main__:Logging message number 5797
# INFO:__main__:Logging message number 5798
# INFO:__main__:Logging message number 5799
# INFO:__main__:Logging message number 5800
# INFO:__main__:Logging message number 5801
# INFO:__main__:Logging message number 5802
# INFO:__main__:Logging message number 5803
# INFO:__main__:Logging message number 5804
# INFO:__main__:Logging message number 5805
# INFO:__main__:Logging message number 5806
# INFO:__main__:Logging message number 5807
# INFO:__main__:Logging message number 5808
# INFO:__main__:Logging message number 5809
# INFO:__main__:Logging message number 5810
# INFO:__main__:Logging message number 5811
# INFO:__main__:Logging message number 5812
# INFO:__main__:Logging message number 5813
# INFO:__main__:Logging message number 5814
# INFO:__main__:Logging message number 5815
# INFO:__main__:Logging message number 5816
# INFO:__main__:Logging message number 5817
# INFO:__main__:Logging message number 5818
# INFO:__main__:Logging message number 5819
# INFO:__main__:Logging message number 5820
# INFO:__main__:Logging message number 5821
# INFO:__main__:Logging message number 5822
# INFO:__main__:Logging message number 5823
# INFO:__main__:Logging message number 5824
# INFO:__main__:Logging message number 5825
# INFO:__main__:Logging message number 5826
# INFO:__main__:Logging message number 5827
# INFO:__main__:Logging message number 5828
# INFO:__main__:Logging message number 5829
# INFO:__main__:Logging message number 5830
# INFO:__main__:Logging message number 5831
# INFO:__main__:Logging message number 5832
# INFO:__main__:Logging message number 5833
# INFO:__main__:Logging message number 5834
# INFO:__main__:Logging message number 5835
# INFO:__main__:Logging message number 5836
# INFO:__main__:Logging message number 5837
# INFO:__main__:Logging message number 5838
# INFO:__main__:Logging message number 5839
# INFO:__main__:Logging message number 5840
# INFO:__main__:Logging message number 5841
# INFO:__main__:Logging message number 5842
# INFO:__main__:Logging message number 5843
# INFO:__main__:Logging message number 5844
# INFO:__main__:Logging message number 5845
# INFO:__main__:Logging message number 5846
# INFO:__main__:Logging message number 5847
# INFO:__main__:Logging message number 5848
# INFO:__main__:Logging message number 5849
# INFO:__main__:Logging message number 5850
# INFO:__main__:Logging message number 5851
# INFO:__main__:Logging message number 5852
# INFO:__main__:Logging message number 5853
# INFO:__main__:Logging message number 5854
# INFO:__main__:Logging message number 5855
# INFO:__main__:Logging message number 5856
# INFO:__main__:Logging message number 5857
# INFO:__main__:Logging message number 5858
# INFO:__main__:Logging message number 5859
# INFO:__main__:Logging message number 5860
# INFO:__main__:Logging message number 5861
# INFO:__main__:Logging message number 5862
# INFO:__main__:Logging message number 5863
# INFO:__main__:Logging message number 5864
# INFO:__main__:Logging message number 5865
# INFO:__main__:Logging message number 5866
# INFO:__main__:Logging message number 5867
# INFO:__main__:Logging message number 5868
# INFO:__main__:Logging message number 5869
# INFO:__main__:Logging message number 5870
# INFO:__main__:Logging message number 5871
# INFO:__main__:Logging message number 5872
# INFO:__main__:Logging message number 5873
# INFO:__main__:Logging message number 5874
# INFO:__main__:Logging message number 5875
# INFO:__main__:Logging message number 5876
# INFO:__main__:Logging message number 5877
# INFO:__main__:Logging message number 5878
# INFO:__main__:Logging message number 5879
# INFO:__main__:Logging message number 5880
# INFO:__main__:Logging message number 5881
# INFO:__main__:Logging message number 5882
# INFO:__main__:Logging message number 5883
# INFO:__main__:Logging message number 5884
# INFO:__main__:Logging message number 5885
# INFO:__main__:Logging message number 5886
# INFO:__main__:Logging message number 5887
# INFO:__main__:Logging message number 5888
# INFO:__main__:Logging message number 5889
# INFO:__main__:Logging message number 5890
# INFO:__main__:Logging message number 5891
# INFO:__main__:Logging message number 5892
# INFO:__main__:Logging message number 5893
# INFO:__main__:Logging message number 5894
# INFO:__main__:Logging message number 5895
# INFO:__main__:Logging message number 5896
# INFO:__main__:Logging message number 5897
# INFO:__main__:Logging message number 5898
# INFO:__main__:Logging message number 5899
# INFO:__main__:Logging message number 5900
# INFO:__main__:Logging message number 5901
# INFO:__main__:Logging message number 5902
# INFO:__main__:Logging message number 5903
# INFO:__main__:Logging message number 5904
# INFO:__main__:Logging message number 5905
# INFO:__main__:Logging message number 5906
# INFO:__main__:Logging message number 5907
# INFO:__main__:Logging message number 5908
# INFO:__main__:Logging message number 5909
# INFO:__main__:Logging message number 5910
# INFO:__main__:Logging message number 5911
# INFO:__main__:Logging message number 5912
# INFO:__main__:Logging message number 5913
# INFO:__main__:Logging message number 5914
# INFO:__main__:Logging message number 5915
# INFO:__main__:Logging message number 5916
# INFO:__main__:Logging message number 5917
# INFO:__main__:Logging message number 5918
# INFO:__main__:Logging message number 5919
# INFO:__main__:Logging message number 5920
# INFO:__main__:Logging message number 5921
# INFO:__main__:Logging message number 5922
# INFO:__main__:Logging message number 5923
# INFO:__main__:Logging message number 5924
# INFO:__main__:Logging message number 5925
# INFO:__main__:Logging message number 5926
# INFO:__main__:Logging message number 5927
# INFO:__main__:Logging message number 5928
# INFO:__main__:Logging message number 5929
# INFO:__main__:Logging message number 5930
# INFO:__main__:Logging message number 5931
# INFO:__main__:Logging message number 5932
# INFO:__main__:Logging message number 5933
# INFO:__main__:Logging message number 5934
# INFO:__main__:Logging message number 5935
# INFO:__main__:Logging message number 5936
# INFO:__main__:Logging message number 5937
# INFO:__main__:Logging message number 5938
# INFO:__main__:Logging message number 5939
# INFO:__main__:Logging message number 5940
# INFO:__main__:Logging message number 5941
# INFO:__main__:Logging message number 5942
# INFO:__main__:Logging message number 5943
# INFO:__main__:Logging message number 5944
# INFO:__main__:Logging message number 5945
# INFO:__main__:Logging message number 5946
# INFO:__main__:Logging message number 5947
# INFO:__main__:Logging message number 5948
# INFO:__main__:Logging message number 5949
# INFO:__main__:Logging message number 5950
# INFO:__main__:Logging message number 5951
# INFO:__main__:Logging message number 5952
# INFO:__main__:Logging message number 5953
# INFO:__main__:Logging message number 5954
# INFO:__main__:Logging message number 5955
# INFO:__main__:Logging message number 5956
# INFO:__main__:Logging message number 5957
# INFO:__main__:Logging message number 5958
# INFO:__main__:Logging message number 5959
# INFO:__main__:Logging message number 5960
# INFO:__main__:Logging message number 5961
# INFO:__main__:Logging message number 5962
# INFO:__main__:Logging message number 5963
# INFO:__main__:Logging message number 5964
# INFO:__main__:Logging message number 5965
# INFO:__main__:Logging message number 5966
# INFO:__main__:Logging message number 5967
# INFO:__main__:Logging message number 5968
# INFO:__main__:Logging message number 5969
# INFO:__main__:Logging message number 5970
# INFO:__main__:Logging message number 5971
# INFO:__main__:Logging message number 5972
# INFO:__main__:Logging message number 5973
# INFO:__main__:Logging message number 5974
# INFO:__main__:Logging message number 5975
# INFO:__main__:Logging message number 5976
# INFO:__main__:Logging message number 5977
# INFO:__main__:Logging message number 5978
# INFO:__main__:Logging message number 5979
# INFO:__main__:Logging message number 5980
# INFO:__main__:Logging message number 5981
# INFO:__main__:Logging message number 5982
# INFO:__main__:Logging message number 5983
# INFO:__main__:Logging message number 5984
# INFO:__main__:Logging message number 5985
# INFO:__main__:Logging message number 5986
# INFO:__main__:Logging message number 5987
# INFO:__main__:Logging message number 5988
# INFO:__main__:Logging message number 5989
# INFO:__main__:Logging message number 5990
# INFO:__main__:Logging message number 5991
# INFO:__main__:Logging message number 5992
# INFO:__main__:Logging message number 5993
# INFO:__main__:Logging message number 5994
# INFO:__main__:Logging message number 5995
# INFO:__main__:Logging message number 5996
# INFO:__main__:Logging message number 5997
# INFO:__main__:Logging message number 5998
# INFO:__main__:Logging message number 5999
# INFO:__main__:Logging message number 6000
# INFO:__main__:Logging message number 6001
# INFO:__main__:Logging message number 6002
# INFO:__main__:Logging message number 6003
# INFO:__main__:Logging message number 6004
# INFO:__main__:Logging message number 6005
# INFO:__main__:Logging message number 6006
# INFO:__main__:Logging message number 6007
# INFO:__main__:Logging message number 6008
# INFO:__main__:Logging message number 6009
# INFO:__main__:Logging message number 6010
# INFO:__main__:Logging message number 6011
# INFO:__main__:Logging message number 6012
# INFO:__main__:Logging message number 6013
# INFO:__main__:Logging message number 6014
# INFO:__main__:Logging message number 6015
# INFO:__main__:Logging message number 6016
# INFO:__main__:Logging message number 6017
# INFO:__main__:Logging message number 6018
# INFO:__main__:Logging message number 6019
# INFO:__main__:Logging message number 6020
# INFO:__main__:Logging message number 6021
# INFO:__main__:Logging message number 6022
# INFO:__main__:Logging message number 6023
# INFO:__main__:Logging message number 6024
# INFO:__main__:Logging message number 6025
# INFO:__main__:Logging message number 6026
# INFO:__main__:Logging message number 6027
# INFO:__main__:Logging message number 6028
# INFO:__main__:Logging message number 6029
# INFO:__main__:Logging message number 6030
# INFO:__main__:Logging message number 6031
# INFO:__main__:Logging message number 6032
# INFO:__main__:Logging message number 6033
# INFO:__main__:Logging message number 6034
# INFO:__main__:Logging message number 6035
# INFO:__main__:Logging message number 6036
# INFO:__main__:Logging message number 6037
# INFO:__main__:Logging message number 6038
# INFO:__main__:Logging message number 6039
# INFO:__main__:Logging message number 6040
# INFO:__main__:Logging message number 6041
# INFO:__main__:Logging message number 6042
# INFO:__main__:Logging message number 6043
# INFO:__main__:Logging message number 6044
# INFO:__main__:Logging message number 6045
# INFO:__main__:Logging message number 6046
# INFO:__main__:Logging message number 6047
# INFO:__main__:Logging message number 6048
# INFO:__main__:Logging message number 6049
# INFO:__main__:Logging message number 6050
# INFO:__main__:Logging message number 6051
# INFO:__main__:Logging message number 6052
# INFO:__main__:Logging message number 6053
# INFO:__main__:Logging message number 6054
# INFO:__main__:Logging message number 6055
# INFO:__main__:Logging message number 6056
# INFO:__main__:Logging message number 6057
# INFO:__main__:Logging message number 6058
# INFO:__main__:Logging message number 6059
# INFO:__main__:Logging message number 6060
# INFO:__main__:Logging message number 6061
# INFO:__main__:Logging message number 6062
# INFO:__main__:Logging message number 6063
# INFO:__main__:Logging message number 6064
# INFO:__main__:Logging message number 6065
# INFO:__main__:Logging message number 6066
# INFO:__main__:Logging message number 6067
# INFO:__main__:Logging message number 6068
# INFO:__main__:Logging message number 6069
# INFO:__main__:Logging message number 6070
# INFO:__main__:Logging message number 6071
# INFO:__main__:Logging message number 6072
# INFO:__main__:Logging message number 6073
# INFO:__main__:Logging message number 6074
# INFO:__main__:Logging message number 6075
# INFO:__main__:Logging message number 6076
# INFO:__main__:Logging message number 6077
# INFO:__main__:Logging message number 6078
# INFO:__main__:Logging message number 6079
# INFO:__main__:Logging message number 6080
# INFO:__main__:Logging message number 6081
# INFO:__main__:Logging message number 6082
# INFO:__main__:Logging message number 6083
# INFO:__main__:Logging message number 6084
# INFO:__main__:Logging message number 6085
# INFO:__main__:Logging message number 6086
# INFO:__main__:Logging message number 6087
# INFO:__main__:Logging message number 6088
# INFO:__main__:Logging message number 6089
# INFO:__main__:Logging message number 6090
# INFO:__main__:Logging message number 6091
# INFO:__main__:Logging message number 6092
# INFO:__main__:Logging message number 6093
# INFO:__main__:Logging message number 6094
# INFO:__main__:Logging message number 6095
# INFO:__main__:Logging message number 6096
# INFO:__main__:Logging message number 6097
# INFO:__main__:Logging message number 6098
# INFO:__main__:Logging message number 6099
# INFO:__main__:Logging message number 6100
# INFO:__main__:Logging message number 6101
# INFO:__main__:Logging message number 6102
# INFO:__main__:Logging message number 6103
# INFO:__main__:Logging message number 6104
# INFO:__main__:Logging message number 6105
# INFO:__main__:Logging message number 6106
# INFO:__main__:Logging message number 6107
# INFO:__main__:Logging message number 6108
# INFO:__main__:Logging message number 6109
# INFO:__main__:Logging message number 6110
# INFO:__main__:Logging message number 6111
# INFO:__main__:Logging message number 6112
# INFO:__main__:Logging message number 6113
# INFO:__main__:Logging message number 6114
# INFO:__main__:Logging message number 6115
# INFO:__main__:Logging message number 6116
# INFO:__main__:Logging message number 6117
# INFO:__main__:Logging message number 6118
# INFO:__main__:Logging message number 6119
# INFO:__main__:Logging message number 6120
# INFO:__main__:Logging message number 6121
# INFO:__main__:Logging message number 6122
# INFO:__main__:Logging message number 6123
# INFO:__main__:Logging message number 6124
# INFO:__main__:Logging message number 6125
# INFO:__main__:Logging message number 6126
# INFO:__main__:Logging message number 6127
# INFO:__main__:Logging message number 6128
# INFO:__main__:Logging message number 6129
# INFO:__main__:Logging message number 6130
# INFO:__main__:Logging message number 6131
# INFO:__main__:Logging message number 6132
# INFO:__main__:Logging message number 6133
# INFO:__main__:Logging message number 6134
# INFO:__main__:Logging message number 6135
# INFO:__main__:Logging message number 6136
# INFO:__main__:Logging message number 6137
# INFO:__main__:Logging message number 6138
# INFO:__main__:Logging message number 6139
# INFO:__main__:Logging message number 6140
# ...
# INFO:__main__:Logging message number 9620
# INFO:__main__:Logging message number 9621
# INFO:__main__:Logging message number 9622
# INFO:__main__:Logging message number 9623
# INFO:__main__:Logging message number 9624
# INFO:__main__:Logging message number 9625
# INFO:__main__:Logging message number 9626
# INFO:__main__:Logging message number 9627
# INFO:__main__:Logging message number 9628
# INFO:__main__:Logging message number 9629
# INFO:__main__:Logging message number 9630
# INFO:__main__:Logging message number 9631
# INFO:__main__:Logging message number 9632
# INFO:__main__:Logging message number 9633
# INFO:__main__:Logging message number 9634
# INFO:__main__:Logging message number 9635
# INFO:__main__:Logging message number 9636
# INFO:__main__:Logging message number 9637
# INFO:__main__:Logging message number 9638
# INFO:__main__:Logging message number 9639
# INFO:__main__:Logging message number 9640
# INFO:__main__:Logging message number 9641
# INFO:__main__:Logging message number 9642
# INFO:__main__:Logging message number 9643
# INFO:__main__:Logging message number 9644
# INFO:__main__:Logging message number 9645
# INFO:__main__:Logging message number 9646
# INFO:__main__:Logging message number 9647
# INFO:__main__:Logging message number 9648
# INFO:__main__:Logging message number 9649
# INFO:__main__:Logging message number 9650
# INFO:__main__:Logging message number 9651
# INFO:__main__:Logging message number 9652
# INFO:__main__:Logging message number 9653
# INFO:__main__:Logging message number 9654
# INFO:__main__:Logging message number 9655
# INFO:__main__:Logging message number 9656
# INFO:__main__:Logging message number 9657
# INFO:__main__:Logging message number 9658
# INFO:__main__:Logging message number 9659
# INFO:__main__:Logging message number 9660
# INFO:__main__:Logging message number 9661
# INFO:__main__:Logging message number 9662
# INFO:__main__:Logging message number 9663
# INFO:__main__:Logging message number 9664
# INFO:__main__:Logging message number 9665
# INFO:__main__:Logging message number 9666
# INFO:__main__:Logging message number 9667
# INFO:__main__:Logging message number 9668
# INFO:__main__:Logging message number 9669
# INFO:__main__:Logging message number 9670
# INFO:__main__:Logging message number 9671
# INFO:__main__:Logging message number 9672
# INFO:__main__:Logging message number 9673
# INFO:__main__:Logging message number 9674
# INFO:__main__:Logging message number 9675
# INFO:__main__:Logging message number 9676
# INFO:__main__:Logging message number 9677
# INFO:__main__:Logging message number 9678
# INFO:__main__:Logging message number 9679
# INFO:__main__:Logging message number 9680
# INFO:__main__:Logging message number 9681
# INFO:__main__:Logging message number 9682
# INFO:__main__:Logging message number 9683
# INFO:__main__:Logging message number 9684
# INFO:__main__:Logging message number 9685
# INFO:__main__:Logging message number 9686
# INFO:__main__:Logging message number 9687
# INFO:__main__:Logging message number 9688
# INFO:__main__:Logging message number 9689
# INFO:__main__:Logging message number 9690
# INFO:__main__:Logging message number 9691
# INFO:__main__:Logging message number 9692
# INFO:__main__:Logging message number 9693
# INFO:__main__:Logging message number 9694
# INFO:__main__:Logging message number 9695
# INFO:__main__:Logging message number 9696
# INFO:__main__:Logging message number 9697
# INFO:__main__:Logging message number 9698
# INFO:__main__:Logging message number 9699
# INFO:__main__:Logging message number 9700
# INFO:__main__:Logging message number 9701
# INFO:__main__:Logging message number 9702
# INFO:__main__:Logging message number 9703
# INFO:__main__:Logging message number 9704
# INFO:__main__:Logging message number 9705
# INFO:__main__:Logging message number 9706
# INFO:__main__:Logging message number 9707
# INFO:__main__:Logging message number 9708
# INFO:__main__:Logging message number 9709
# INFO:__main__:Logging message number 9710
# INFO:__main__:Logging message number 9711
# INFO:__main__:Logging message number 9712
# INFO:__main__:Logging message number 9713
# INFO:__main__:Logging message number 9714
# INFO:__main__:Logging message number 9715
# INFO:__main__:Logging message number 9716
# INFO:__main__:Logging message number 9717
# INFO:__main__:Logging message number 9718
# INFO:__main__:Logging message number 9719
# INFO:__main__:Logging message number 9720
# INFO:__main__:Logging message number 9721
# INFO:__main__:Logging message number 9722
# INFO:__main__:Logging message number 9723
# INFO:__main__:Logging message number 9724
# INFO:__main__:Logging message number 9725
# INFO:__main__:Logging message number 9726
# INFO:__main__:Logging message number 9727
# INFO:__main__:Logging message number 9728
# INFO:__main__:Logging message number 9729
# INFO:__main__:Logging message number 9730
# INFO:__main__:Logging message number 9731
# INFO:__main__:Logging message number 9732
# INFO:__main__:Logging message number 9733
# INFO:__main__:Logging message number 9734
# INFO:__main__:Logging message number 9735
# INFO:__main__:Logging message number 9736
# INFO:__main__:Logging message number 9737
# INFO:__main__:Logging message number 9738
# INFO:__main__:Logging message number 9739
# INFO:__main__:Logging message number 9740
# INFO:__main__:Logging message number 9741
# INFO:__main__:Logging message number 9742
# INFO:__main__:Logging message number 9743
# INFO:__main__:Logging message number 9744
# INFO:__main__:Logging message number 9745
# INFO:__main__:Logging message number 9746
# INFO:__main__:Logging message number 9747
# INFO:__main__:Logging message number 9748
# INFO:__main__:Logging message number 9749
# INFO:__main__:Logging message number 9750
# INFO:__main__:Logging message number 9751
# INFO:__main__:Logging message number 9752
# INFO:__main__:Logging message number 9753
# INFO:__main__:Logging message number 9754
# INFO:__main__:Logging message number 9755
# INFO:__main__:Logging message number 9756
# INFO:__main__:Logging message number 9757
# INFO:__main__:Logging message number 9758
# INFO:__main__:Logging message number 9759
# INFO:__main__:Logging message number 9760
# INFO:__main__:Logging message number 9761
# INFO:__main__:Logging message number 9762
# INFO:__main__:Logging message number 9763
# INFO:__main__:Logging message number 9764
# INFO:__main__:Logging message number 9765
# INFO:__main__:Logging message number 9766
# INFO:__main__:Logging message number 9767
# INFO:__main__:Logging message number 9768
# INFO:__main__:Logging message number 9769
# INFO:__main__:Logging message number 9770
# INFO:__main__:Logging message number 9771
# INFO:__main__:Logging message number 9772
# INFO:__main__:Logging message number 9773
# INFO:__main__:Logging message number 9774
# INFO:__main__:Logging message number 9775
# INFO:__main__:Logging message number 9776
# INFO:__main__:Logging message number 9777
# INFO:__main__:Logging message number 9778
# INFO:__main__:Logging message number 9779
# INFO:__main__:Logging message number 9780
# INFO:__main__:Logging message number 9781
# INFO:__main__:Logging message number 9782
# INFO:__main__:Logging message number 9783
# INFO:__main__:Logging message number 9784
# INFO:__main__:Logging message number 9785
# INFO:__main__:Logging message number 9786
# INFO:__main__:Logging message number 9787
# INFO:__main__:Logging message number 9788
# INFO:__main__:Logging message number 9789
# INFO:__main__:Logging message number 9790
# INFO:__main__:Logging message number 9791
# INFO:__main__:Logging message number 9792
# INFO:__main__:Logging message number 9793
# INFO:__main__:Logging message number 9794
# INFO:__main__:Logging message number 9795
# INFO:__main__:Logging message number 9796
# INFO:__main__:Logging message number 9797
# INFO:__main__:Logging message number 9798
# INFO:__main__:Logging message number 9799
# INFO:__main__:Logging message number 9800
# INFO:__main__:Logging message number 9801
# INFO:__main__:Logging message number 9802
# INFO:__main__:Logging message number 9803
# INFO:__main__:Logging message number 9804
# INFO:__main__:Logging message number 9805
# INFO:__main__:Logging message number 9806
# INFO:__main__:Logging message number 9807
# INFO:__main__:Logging message number 9808
# INFO:__main__:Logging message number 9809
# INFO:__main__:Logging message number 9810
# INFO:__main__:Logging message number 9811
# INFO:__main__:Logging message number 9812
# INFO:__main__:Logging message number 9813
# INFO:__main__:Logging message number 9814
# INFO:__main__:Logging message number 9815
# INFO:__main__:Logging message number 9816
# INFO:__main__:Logging message number 9817
# INFO:__main__:Logging message number 9818
# INFO:__main__:Logging message number 9819
# INFO:__main__:Logging message number 9820
# INFO:__main__:Logging message number 9821
# INFO:__main__:Logging message number 9822
# INFO:__main__:Logging message number 9823
# INFO:__main__:Logging message number 9824
# INFO:__main__:Logging message number 9825
# INFO:__main__:Logging message number 9826
# INFO:__main__:Logging message number 9827
# INFO:__main__:Logging message number 9828
# INFO:__main__:Logging message number 9829
# INFO:__main__:Logging message number 9830
# INFO:__main__:Logging message number 9831
# INFO:__main__:Logging message number 9832
# INFO:__main__:Logging message number 9833
# INFO:__main__:Logging message number 9834
# INFO:__main__:Logging message number 9835
# INFO:__main__:Logging message number 9836
# INFO:__main__:Logging message number 9837
# INFO:__main__:Logging message number 9838
# INFO:__main__:Logging message number 9839
# INFO:__main__:Logging message number 9840
# INFO:__main__:Logging message number 9841
# INFO:__main__:Logging message number 9842
# INFO:__main__:Logging message number 9843
# INFO:__main__:Logging message number 9844
# INFO:__main__:Logging message number 9845
# INFO:__main__:Logging message number 9846
# INFO:__main__:Logging message number 9847
# INFO:__main__:Logging message number 9848
# INFO:__main__:Logging message number 9849
# INFO:__main__:Logging message number 9850
# INFO:__main__:Logging message number 9851
# INFO:__main__:Logging message number 9852
# INFO:__main__:Logging message number 9853
# INFO:__main__:Logging message number 9854
# INFO:__main__:Logging message number 9855
# INFO:__main__:Logging message number 9856
# INFO:__main__:Logging message number 9857
# INFO:__main__:Logging message number 9858
# INFO:__main__:Logging message number 9859
# INFO:__main__:Logging message number 9860
# INFO:__main__:Logging message number 9861
# INFO:__main__:Logging message number 9862
# INFO:__main__:Logging message number 9863
# INFO:__main__:Logging message number 9864
# INFO:__main__:Logging message number 9865
# INFO:__main__:Logging message number 9866
# INFO:__main__:Logging message number 9867
# INFO:__main__:Logging message number 9868
# INFO:__main__:Logging message number 9869
# INFO:__main__:Logging message number 9870
# INFO:__main__:Logging message number 9871
# INFO:__main__:Logging message number 9872
# INFO:__main__:Logging message number 9873
# INFO:__main__:Logging message number 9874
# INFO:__main__:Logging message number 9875
# INFO:__main__:Logging message number 9876
# INFO:__main__:Logging message number 9877
# INFO:__main__:Logging message number 9878
# INFO:__main__:Logging message number 9879
# INFO:__main__:Logging message number 9880
# INFO:__main__:Logging message number 9881
# INFO:__main__:Logging message number 9882
# INFO:__main__:Logging message number 9883
# INFO:__main__:Logging message number 9884
# INFO:__main__:Logging message number 9885
# INFO:__main__:Logging message number 9886
# INFO:__main__:Logging message number 9887
# INFO:__main__:Logging message number 9888
# INFO:__main__:Logging message number 9889
# INFO:__main__:Logging message number 9890
# INFO:__main__:Logging message number 9891
# INFO:__main__:Logging message number 9892
# INFO:__main__:Logging message number 9893
# INFO:__main__:Logging message number 9894
# INFO:__main__:Logging message number 9895
# INFO:__main__:Logging message number 9896
# INFO:__main__:Logging message number 9897
# INFO:__main__:Logging message number 9898
# INFO:__main__:Logging message number 9899
# INFO:__main__:Logging message number 9900
# INFO:__main__:Logging message number 9901
# INFO:__main__:Logging message number 9902
# INFO:__main__:Logging message number 9903
# INFO:__main__:Logging message number 9904
# INFO:__main__:Logging message number 9905
# INFO:__main__:Logging message number 9906
# INFO:__main__:Logging message number 9907
# INFO:__main__:Logging message number 9908
# INFO:__main__:Logging message number 9909
# INFO:__main__:Logging message number 9910
# INFO:__main__:Logging message number 9911
# INFO:__main__:Logging message number 9912
# INFO:__main__:Logging message number 9913
# INFO:__main__:Logging message number 9914
# INFO:__main__:Logging message number 9915
# INFO:__main__:Logging message number 9916
# INFO:__main__:Logging message number 9917
# INFO:__main__:Logging message number 9918
# INFO:__main__:Logging message number 9919
# INFO:__main__:Logging message number 9920
# INFO:__main__:Logging message number 9921
# INFO:__main__:Logging message number 9922
# INFO:__main__:Logging message number 9923
# INFO:__main__:Logging message number 9924
# INFO:__main__:Logging message number 9925
# INFO:__main__:Logging message number 9926
# INFO:__main__:Logging message number 9927
# INFO:__main__:Logging message number 9928
# INFO:__main__:Logging message number 9929
# INFO:__main__:Logging message number 9930
# INFO:__main__:Logging message number 9931
# INFO:__main__:Logging message number 9932
# INFO:__main__:Logging message number 9933
# INFO:__main__:Logging message number 9934
# INFO:__main__:Logging message number 9935
# INFO:__main__:Logging message number 9936
# INFO:__main__:Logging message number 9937
# INFO:__main__:Logging message number 9938
# INFO:__main__:Logging message number 9939
# INFO:__main__:Logging message number 9940
# INFO:__main__:Logging message number 9941
# INFO:__main__:Logging message number 9942
# INFO:__main__:Logging message number 9943
# INFO:__main__:Logging message number 9944
# INFO:__main__:Logging message number 9945
# INFO:__main__:Logging message number 9946
# INFO:__main__:Logging message number 9947
# INFO:__main__:Logging message number 9948
# INFO:__main__:Logging message number 9949
# INFO:__main__:Logging message number 9950
# INFO:__main__:Logging message number 9951
# INFO:__main__:Logging message number 9952
# INFO:__main__:Logging message number 9953
# INFO:__main__:Logging message number 9954
# INFO:__main__:Logging message number 9955
# INFO:__main__:Logging message number 9956
# INFO:__main__:Logging message number 9957
# INFO:__main__:Logging message number 9958
# INFO:__main__:Logging message number 9959
# INFO:__main__:Logging message number 9960
# INFO:__main__:Logging message number 9961
# INFO:__main__:Logging message number 9962
# INFO:__main__:Logging message number 9963
# INFO:__main__:Logging message number 9964
# INFO:__main__:Logging message number 9965
# INFO:__main__:Logging message number 9966
# INFO:__main__:Logging message number 9967
# INFO:__main__:Logging message number 9968
# INFO:__main__:Logging message number 9969
# INFO:__main__:Logging message number 9970
# INFO:__main__:Logging message number 9971
# INFO:__main__:Logging message number 9972
# INFO:__main__:Logging message number 9973
# INFO:__main__:Logging message number 9974
# INFO:__main__:Logging message number 9975
# INFO:__main__:Logging message number 9976
# INFO:__main__:Logging message number 9977
# INFO:__main__:Logging message number 9978
# INFO:__main__:Logging message number 9979
# INFO:__main__:Logging message number 9980
# INFO:__main__:Logging message number 9981
# INFO:__main__:Logging message number 9982
# INFO:__main__:Logging message number 9983
# INFO:__main__:Logging message number 9984
# INFO:__main__:Logging message number 9985
# INFO:__main__:Logging message number 9986
# INFO:__main__:Logging message number 9987
# INFO:__main__:Logging message number 9988
# INFO:__main__:Logging message number 9989
# INFO:__main__:Logging message number 9990
# INFO:__main__:Logging message number 9991
# INFO:__main__:Logging message number 9992
# INFO:__main__:Logging message number 9993
# INFO:__main__:Logging message number 9994
# INFO:__main__:Logging message number 9995
# INFO:__main__:Logging message number 9996
# INFO:__main__:Logging message number 9997
# INFO:__main__:Logging message number 9998
# INFO:__main__:Logging message number 9999

# %% [markdown]
# 19. Write a program that handles IndexError and KeyError using a try-except block.

# %%
my_list = [1, 2, 3]
my_dict = {"a": 1, "b": 2}

try:
    print(my_list[2])  # This will cause an IndexError
    print(my_dict["c"]) # This will cause a KeyError
except IndexError:
    print("Error: Index out of bounds.")
except KeyError:
    print("Error: Key not found in dictionary.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# 3
# Error: Key not found in dictionary.

# %% [markdown]
# 20. How would you open a file and read its contents using a context manager in Python?

# %%
try:
    with open("my_file.txt", "r") as file:
        content = file.read()
        print("File content:\n", content)
    # The file is automatically closed here
except FileNotFoundError:
    print("Error: The file was not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# File content:
#  Hello, world!

# %% [markdown]
# 21. Write a Python program that reads a file and prints the number of occurrences of a specific word.

# %%
def count_word_occurrences(file_path, word):
    try:
        with open(file_path, "r") as file:
            content = file.read().lower()
            words = content.split()
            count = words.count(word.lower())
            print(f"The word '{word}' appears {count} times in '{file_path}'.")
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' was not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

count_word_occurrences("src.txt", "Hello")
# Out:
# The word 'Hello' appears 2 times in 'src.txt'.

# %% [markdown]
# 22. How can you check if a file is empty before attempting to read its contents?

# %%
def is_file_empty_by_reading(file_path):
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            return not bool(content)
    except FileNotFoundError:
        print(f"Error: File not found: {file_path}")
        return True

# Example usage:
file_path = "src.txt"

# Create the file if it doesn't exist
with open(file_path, 'w') as f:
    pass

if is_file_empty_by_reading(file_path):
    print(f"Before:The file '{file_path}' is empty.")
else:
    print(f"Before:The file '{file_path}' is not empty.")

with open(file_path, 'w') as f:
    f.write("Some content")

if is_file_empty_by_reading(file_path):
    print(f"After: The file '{file_path}' is empty.")
else:
    print(f"After: The file '{file_path}' is not empty.")
# Out:
# Before:The file 'src.txt' is empty.
# After: The file 'src.txt' is not empty.

# %% [markdown]
# 23. Write a Python program that writes to a log file when an error occurs during file handling.

# %%
import logging

# Configure logging to write to a file
logging.basicConfig(filename='file_handling_errors.log', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

def read_file_safely(filename):
    try:
        with open(filename, 'r') as f:
            content = f.read()
        print(f"Content of {filename}:\n{content}")
    except FileNotFoundError:
        logging.error(f"File not found: {filename}")
        print(f"Error: File not found - {filename}.  Check the file path and name.")
    except IOError as e:
        logging.error(f"IOError occurred while reading {filename}: {e}")
        print(f"Error reading file {filename}: {e}")
    except Exception as e:
        logging.error(f"An unexpected error occurred while reading {filename}: {e}")
        print(f"An unexpected error occurred while reading {filename}: {e}")

def write_file_safely(filename, data):
    try:
        with open(filename, 'w') as f:
            f.write(data)
        print(f"Data successfully written to {filename}")
    except IOError as e:
        logging.error(f"IOError occurred while writing to {filename}: {e}")
        print(f"Error writing to file {filename}: {e}")
    except Exception as e:
        logging.error(f"An unexpected error occurred while writing to {filename}: {e}")
        print(f"An unexpected error occurred while writing to {filename}: {e}")

if __name__ == "__main__":
    # Example usage
    read_file_safely("non_existent_file.txt")  # This will cause a FileNotFoundError
    read_file_safely("src.txt") #This will work if the file exists

    write_file_safely("src.txt", "Hello, world!")  # This should work
    write_file_safely("/invalid/directory/file.txt", "Some data")  # This will cause an IOError if the directory is invalid

    read_file_safely("src.txt")
# Out:
# ERROR:root:File not found: non_existent_file.txt
# ERROR:root:IOError occurred while writing to /invalid/directory/file.txt: [Errno 2] No such file or directory: '/invalid/directory/file.txt'
# Error: File not found - non_existent_file.txt.  Check the file path and name.
# Content of src.txt:
# Some content
# Data successfully written to src.txt
# Error writing to file /invalid/directory/file.txt: [Errno 2] No such file or directory: '/invalid/directory/file.txt'
# Content of src.txt:
# Hello, world!
